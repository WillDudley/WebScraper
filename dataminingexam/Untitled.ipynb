# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
df = pd.read_csv("Untitled spreadsheet - Sheet1.csv", index_col=0)

# %%
df = df.notna()

# %%
df = df.transpose()

# %%
df.head()
# Out:
#       TF IDF  Jaccard sim of sets  Jaccard sim of bags  \
# 2018    True                 True                 True
# 2017    True                 True                 True
# 2016   False                 True                 True
# 2015    True                False                False
# 2014    True                False                False
#
#       Jaccard sim of bags UB proof  Jaccard distance  Distance measure proofs  \
# 2018                          True              True                     True
# 2017                          True              True                     True
# 2016                          True              True                     True
# 2015                         False             False                     True
# 2014                         False             False                     True
#
#       kNN (weighted and unweighted)  Edit distance  Naive Bayesian  \
# 2018                           True           True            True
# ...

# %%
counts_df = df.apply(pd.Series.value_counts)

# %%
counts_df = counts_df.transpose()

# %%
counts_df.columns
# Out:
# Index([False, True], dtype='object')

# %%
counts_df = counts_df.drop(columns=[False])

# %%
counts_df.sort_values(by=[True], inplace=True)

# %%
counts_df.columns = ['Number of times topic has appeared in the last seven exams']

# %%
font = {'family' : 'normal',
        'weight' : 'bold',
        'size'   : 22}

plt.rc('font', **font)

# %%
counts_df.plot.barh(figsize=(6,32), legend=False)
plt.savefig('dataminingexams.pdf')
